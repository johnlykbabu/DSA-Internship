# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:/Users/hp/OneDrive/Desktop/DSA Internship/StudentsPerformance.csv")

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
data.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.001000      69.195000      68.119000
# std      15.569567      14.706436      15.226381
# min       0.000000      17.000000      10.000000
# 25%      57.000000      59.000000      58.000000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.250000      79.000000
# max     100.000000     100.000000     100.000000

# %%
data.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
#Find out how many males and females participated in the test.
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
# What do you think about the students' parental level of education?
data.groupby(['parental level of education','race/ethnicity']).sum()
# Out:
#                                             math score  reading score  \
# parental level of education race/ethnicity
# associate's degree          group A                854            939
#                             group B               2731           2873
#                             group C               5205           5548
#                             group D               3380           3527
#                             group E               2921           2879
# bachelor's degree           group A                806            817
#                             group B               1386           1459
#                             group C               2714           3027
#                             group D               1892           1964
#                             group E               1378           1347
# high school                 group A               1088           1132
#                             group B               2878           3066
# ...

# %%
scores=data.groupby(['math score','reading score','writing score','gender']).size().reset_index()
scores
# Out:
#      math score  reading score  writing score  gender  0
# 0             0             17             10  female  1
# 1             8             24             23  female  1
# 2            11             38             32  female  1
# 3            13             41             51  female  1
# 4            18             32             28  female  1
# ..          ...            ...            ...     ... ..
# 980         100             96             86    male  1
# 981         100             97             99    male  1
# 982         100            100             93    male  1
# 983         100            100            100  female  2
# 984         100            100            100    male  1
#
# [985 rows x 5 columns]

# %%
df=scores[['math score','reading score','writing score']].mean()
df
# Out:
# math score       65.917766
# reading score    69.045685
# writing score    67.976650
# dtype: float64

# %%
#Who scores the most on average for math, reading and writing based on Gender?
df2=data.groupby('gender')[['math score','reading score','writing score']].mean()
df2
# Out:
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %%
#Who scores the most on average for math, reading and writing based on Test Preparation Course?
df2=data.groupby('test preparation course')[['math score','reading score','writing score']].mean()
df2
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %%
#What do you think about the scoring variation for math, reading and writing based on Gender:
df3=data.groupby('gender')[['math score','reading score','writing score']].var()
df3
# Out:
#         math score  reading score  writing score
# gender
# female  256.958593     207.677438     220.369327
# male    211.889097     200.211010     202.413924

# %%
#What do you think about the scoring variation for math, reading and writing based on Test preparation course:
df4=data.groupby('test preparation course')[['math score','reading score','writing score']].var()
df4
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                210.884027     183.265864     175.202612
# none                     246.668662     213.419851     226.251739

# %%
#The management needs your help to give bonus points to the top 25% of students based on their math score, so how will you help the management to achieve this:
data.quantile(.75,axis=0)
# Out:
# math score       77.00
# reading score    79.25
# writing score    79.00
# Name: 0.75, dtype: float64

# %%
data.nlargest(77,'math score')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 515  female        group E                some college      standard
# 516  female        group E           bachelor's degree      standard
# 517  female        group E          associate's degree      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 951    male        group B                some college      standard
# 952    male        group B           bachelor's degree  free/reduced
# 953    male        group C                 high school      standard
# 954    male        group D                 high school      standard
# 955    male        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...
